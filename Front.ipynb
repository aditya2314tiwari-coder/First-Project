# %%
import pandas as pd
Credit = pd.read_csv(r"C:\Users\ASUS\Downloads\Credit Banking_Project1.csv", encoding="UTF-8")
print(Credit)
# Out:
#     Sl No: Customer      Age        City Credit Card Product            Limit  \
# 0        1       A1   0.9285   BANGALORE                Gold  INR 5,00,000.00
# 1        2       A2  35.5346    CALCUTTA              Silver  INR 1,00,000.00
# 2        3       A3  11.5593      COCHIN            Platimum    INR 10,000.00
# 3        4       A4  45.8203      BOMBAY            Platimum    INR 10,001.00
# 4        5       A5  69.6639   BANGALORE            Platimum    INR 10,002.00
# ..     ...      ...      ...         ...                 ...              ...
# 95      96      A96  29.6316     CHENNAI              Silver  INR 1,00,000.00
# 96      97      A97  20.6118  TRIVANDRUM            Platimum    INR 10,000.00
# 97      98      A98  40.5390    CALCUTTA            Platimum    INR 10,001.00
# 98      99      A99  21.5887    CALCUTTA            Platimum    INR 10,002.00
# 99     100     A100  23.6076      COCHIN              Silver  INR 1,00,000.00
#
#    Company        Segment
# ...

# %%
repay= pd.read_csv(r"C:\Users\ASUS\Downloads\repayment.csv", encoding= "UTF-8")
print(repay)
# Out:
#       SL No: Costomer      Month         Amount  Unnamed: 4
# 0        1.0       A1  12-Jan-04  331844.007400         NaN
# 1        2.0       A1   3-Jan-04  441139.807300         NaN
# 2        3.0       A1  15-Jan-04   32480.004010         NaN
# 3        4.0       A1  25-Jan-04   90636.966530         NaN
# 4        5.0       A1  17-Jan-05    1581.969829         NaN
# ...      ...      ...        ...            ...         ...
# 1518     NaN      NaN        NaN            NaN         NaN
# 1519     NaN      NaN        NaN            NaN         NaN
# 1520     NaN      NaN        NaN            NaN         NaN
# 1521     NaN      NaN        NaN            NaN         NaN
# 1522     NaN      NaN        NaN            NaN         NaN
#
# [1523 rows x 5 columns]

# %%
Spend=  pd.read_csv(r"C:\Users\ASUS\Downloads\spend.csv", encoding= "UTF-8")
print(Spend)
# Out:
#       Sl No: Costomer      Month        Type  Amount
# 0          1       A1  12-Jan-04   JEWELLERY  473776
# 1          2       A1   3-Jan-04       PETRO  335579
# 2          3       A1  15-Jan-04     CLOTHES  371041
# 3          4       A1  25-Jan-04        FOOD  141178
# 4          5       A1  17-Jan-05      CAMERA  398404
# ...      ...      ...        ...         ...     ...
# 1495    1496      A67   4-Feb-06  BUS TICKET  195841
# 1496    1497      A68  25-Mar-06  BUS TICKET  284263
# 1497    1498      A69  31-Mar-06  BUS TICKET  206552
# 1498    1499      A70  23-Mar-06  BUS TICKET   41025
# 1499    1500      A71  24-Mar-06  BUS TICKET  101398
#
# [1500 rows x 5 columns]

# %%
repay.rename(columns={"Costomer":"Customer"},inplace= True)
repay
# Out:
#       SL No: Customer      Month         Amount  Unnamed: 4
# 0        1.0       A1  12-Jan-04  331844.007400         NaN
# 1        2.0       A1   3-Jan-04  441139.807300         NaN
# 2        3.0       A1  15-Jan-04   32480.004010         NaN
# 3        4.0       A1  25-Jan-04   90636.966530         NaN
# 4        5.0       A1  17-Jan-05    1581.969829         NaN
# ...      ...      ...        ...            ...         ...
# 1518     NaN      NaN        NaN            NaN         NaN
# 1519     NaN      NaN        NaN            NaN         NaN
# 1520     NaN      NaN        NaN            NaN         NaN
# 1521     NaN      NaN        NaN            NaN         NaN
# 1522     NaN      NaN        NaN            NaN         NaN
#
# [1523 rows x 5 columns]

# %%
Spend.rename(columns={"Costomer":"Customer"},inplace= True)
Spend
# Out:
#       Sl No: Customer      Month        Type  Amount
# 0          1       A1  12-Jan-04   JEWELLERY  473776
# 1          2       A1   3-Jan-04       PETRO  335579
# 2          3       A1  15-Jan-04     CLOTHES  371041
# 3          4       A1  25-Jan-04        FOOD  141178
# 4          5       A1  17-Jan-05      CAMERA  398404
# ...      ...      ...        ...         ...     ...
# 1495    1496      A67   4-Feb-06  BUS TICKET  195841
# 1496    1497      A68  25-Mar-06  BUS TICKET  284263
# 1497    1498      A69  31-Mar-06  BUS TICKET  206552
# 1498    1499      A70  23-Mar-06  BUS TICKET   41025
# 1499    1500      A71  24-Mar-06  BUS TICKET  101398
#
# [1500 rows x 5 columns]

# %%
mean= Credit[Credit["Age"]>18]["Age"].mean()
mean
# Out:
# np.float64(49.29243076923076)

# %%
Credit.loc[Credit["Age"]<18, "Age"]= mean
Credit
# Out:
#     Sl No: Customer        Age        City Credit Card Product  \
# 0        1       A1  49.292431   BANGALORE                Gold
# 1        2       A2  35.534600    CALCUTTA              Silver
# 2        3       A3  49.292431      COCHIN            Platimum
# 3        4       A4  45.820300      BOMBAY            Platimum
# 4        5       A5  69.663900   BANGALORE            Platimum
# ..     ...      ...        ...         ...                 ...
# 95      96      A96  29.631600     CHENNAI              Silver
# 96      97      A97  20.611800  TRIVANDRUM            Platimum
# 97      98      A98  40.539000    CALCUTTA            Platimum
# 98      99      A99  21.588700    CALCUTTA            Platimum
# 99     100     A100  23.607600      COCHIN              Silver
#
#               Limit Company        Segment
# 0   INR 5,00,000.00      C1  Self Employed
# 1   INR 1,00,000.00      C2   Salaried_MNC
# 2     INR 10,000.00      C3   Salaried_Pvt
# ...

# %%
repay.drop("Unnamed: 4", axis=1, inplace= True)

# %%
Spend
# Out:
#       Sl No: Customer      Month        Type  Amount
# 0          1       A1  12-Jan-04   JEWELLERY  473776
# 1          2       A1   3-Jan-04       PETRO  335579
# 2          3       A1  15-Jan-04     CLOTHES  371041
# 3          4       A1  25-Jan-04        FOOD  141178
# 4          5       A1  17-Jan-05      CAMERA  398404
# ...      ...      ...        ...         ...     ...
# 1495    1496      A67   4-Feb-06  BUS TICKET  195841
# 1496    1497      A68  25-Mar-06  BUS TICKET  284263
# 1497    1498      A69  31-Mar-06  BUS TICKET  206552
# 1498    1499      A70  23-Mar-06  BUS TICKET   41025
# 1499    1500      A71  24-Mar-06  BUS TICKET  101398
#
# [1500 rows x 5 columns]

# %%
repay
# Out:
#      Customer      Month         Amount
# 0          A1  12-Jan-04  331844.007400
# 1          A1   3-Jan-04  441139.807300
# 2          A1  15-Jan-04   32480.004010
# 3          A1  25-Jan-04   90636.966530
# 4          A1  17-Jan-05    1581.969829
# ...       ...        ...            ...
# 1518      NaN        NaN            NaN
# 1519      NaN        NaN            NaN
# 1520      NaN        NaN            NaN
# 1521      NaN        NaN            NaN
# 1522      NaN        NaN            NaN
#
# [1523 rows x 3 columns]
