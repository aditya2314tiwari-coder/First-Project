# %%
l=["Apple","Banana","Grapes","mango"]
print(l)
# Out:
# ['Apple', 'Banana', 'Grapes', 'mango']

# %%
l1=["1","2","3"]
l2=["hello","hi","hhehe"]
a={"e":l1, "f":l2, "g":23}
print(a)
# Out:
# {'e': ['1', '2', '3'], 'f': ['hello', 'hi', 'hhehe'], 'g': 23}

# %%
a=12
b=4
print({'Addition(a+b),(a-b),(a*b),(a/b),(a//b),(a%b))
# Out:
# 16 8 48 3.0 3 0

# %%
a=int(input("enter the no."))
print(a)
# Out:
# enter the no. 1234567899435346346456
# 1234567899435346346456

# %%
a=input("enter the word u want")
b=input("enter the your emotions that u want to express")
print(a+b)
# Out:
# enter the word u want Felling
# enter the your emotions that u want to express in love
# Fellingin love

# %%
a=input("enter the word u want")
b=input("enter the your emotions that u want to express")
print(a+b)
# Out:
# enter the word u want Falling
# enter the your emotions that u want to express in love
# Fallingin love

# %%
a=int(input("enter the no.")) # 6
b = a/ 4
c = a/ 2
d = a/ 6
sum = b+c+d

if a == sum :
    {print("perfect")}
else:
    print("not perfect")
# Out:
# enter the no. 12
# not perfect

# %%
a=int(input("enter the no.")) # 6
b = a/ 4
c = a/ 2
d = a/ 6
sum = b+c+d

if a == sum :
    {print("perfect")}
else:
    print("not perfect")
# Out:
# enter the no. 12
# not perfect

# %%
a=int(input("enter the no."))
b+Int(input("enter the no."))
if a==b:
    print("both no. is equal")
elif
