# %%
print("Aditya")
# Out:
# Aditya

# %%
#take three values 
a=int(input(" enter the no. "))
b=input("enterr the  words")
c=int(input(" enter the no. what  u want"))
print(a,b,c)
# Out:
#  enter the no.  12
# enterr the  words 1222
#  enter the no. what  u want 12222222222222
# 12 1222 12222222222222

# %%
a=" AdityaTiwari"
susstrinn= a[0:10:2]
print(susstrinn)
# Out:
#  dtai

# %%
a=int(input("enter the no."))
b= (a%2==0)
c=(a%3==0)
d=(a%1==0)
if (b+c+d==a):
    print("this is perfect no.")
else:
    print("this is not perfect no.")
# Out:
# enter the no. 12
# this is not perfect no.

# %%
##Slicing Of String

# %%
b= a[::-1]
print(b)
# Out:
# irawiTaytidA

# %%
c= a[:-12:-1]
print(c)
# Out:
# irawiTaytid

# %%
d= a[-11:]
print(d)
# Out:
# dityaTiwari

# %%
e= a[-16:-1]
print(e)
# Out:
#  AdityaTiwar

# %%
text= "hello India"
a= text.split()
print(a)
# Out:
# ['hello', 'India']

# %%
text= "hello India"
b= " ".join(text)
print(b)
# Out:
# h e l l o   I n d i a

# %%
text= "hello India"
c= text.capitalize()
print(c)
# Out:
# Hello india

# %%
text= "hello India"
d= text.upper()
print(d)
# Out:
# HELLO INDIA

# %%
text= "hello India"
e= text.lower()
print(e)
# Out:
# hello india

# %%
text= "hello India"
print(text.count(i))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 text= "hello India"
# ----> 2 print(text.count(i))
#
# NameError: name 'i' is not defined

# %%
x=int(input("  "))
if x%2
